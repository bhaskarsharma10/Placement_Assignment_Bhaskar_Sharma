# %%
# Moving Zeroes
def MoveZeroes(nums):
    zero_count=0
    for i in nums:
        if i==0:
            nums.remove(i)
            zero_count=zero_count+1
    nums.extend([0]*zero_count)
    return nums
